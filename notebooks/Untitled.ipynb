# %%
# !pip install uproot pandas matplotlib seaborn

# %%
from pyspark.sql import SparkSession
import os

spark = SparkSession.builder.appName("HiggsBosonAnalysis").master("spark://spark-master:7077").config("spark.executor.memory", "2g").getOrCreate()

print("✅ SparkSession created successfully!")
